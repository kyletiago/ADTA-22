# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

census = pd.read_csv("Census.csv")

# %%
# Change -9 values to 0
newCensus = census.replace(-9, 0)
newCensus.dropna(inplace=True)
del newCensus['Person ID']
del newCensus['Residence Type']
newCensus.head()
# Out:
#            Region  Family Composition  Population Base  Sex  Age  \
# 302321  E12000001                   5                1    2    5
# 302322  E12000001                   2                1    2    2
# 302323  E12000001                   2                1    2    5
# 302324  E12000001                   2                1    2    6
# 302325  E12000001                   5                1    2    6
#
#         Marital Status  Student  Country of Birth  Health  Ethnic Group  \
# 302321               4        2                 1       3             1
# 302322               1        1                 1       1             1
# 302323               2        2                 1       3             1
# 302324               2        2                 1       1             1
# 302325               3        2                 1       2             1
#
#         Religion  Economic Activity  Occupation  Industry  \
# 302321         2                  2           7         7
# ...

# %%
region = {
    "E12000001": "North East",
    "E12000002": "North West",
    "E12000003": "Yorkshire and the Humber",
    "E12000004": "East Midlands",
    "E12000005": "West Midlands",
    "E12000006": "East of England",
    "E12000007": "London",
    "E12000008": "South East",
    "E12000009": "South West",
    "W92000004": "Wales"
}

family_composition = {
    1: "Not in a family",
    2: "Married/same-sex civil partnership couple family",
    3: "Cohabiting couple family",
    4: "Lone parent family (male head)",
    5: "Lone parent family (female head)",
    6: "Other related family"
}

population_base = {
    1: "Usual resident",
    2: "Student living away from home during term-time",
    3: "Short-term resident"
}

sex = {
    1: "Male",
    2: "Female"
}

age = {
    1: "0 to 15",
    2: "16 to 24",
    3: "25 to 34",
    4: "35 to 44",
    5: "45 to 54",
    6: "55 to 64",
    7: "65 to 74",
    8: "75 and over"
}

marital_status = {
    1: "Single (never married or never registered a same-sex civil partnership)",
    2: "Married or in a registered same-sex civil partnership",
    3: "Separated but still legally married or separated but still legally in a same-sex civil partnership",
    4: "Divorced or formerly in a same-sex civil partnership which is now legally dissolved",
    5: "Widowed or surviving partner from a same-sex civil partnership"
}

student = {
    1: "Yes",
    2: "No"
}

country_of_birth = {
    1: "UK",
    2: "Non UK"
}

health = {
    1: "Very good health",
    2: "Good health",
    3: "Fair health",
    4: "Bad health",
    5: "Very bad health"
}

ethnic_group = {
    1: "White",
    2: "Mixed",
    3: "Asian and Asian British",
    4: "Black or Black British",
    5: "Chinese or Other ethnic group"
}

religion = {
    1: "No religion",
    2: "Christian",
    3: "Buddhist",
    4: "Hindu",
    5: "Jewish",
    6: "Muslim",
    7: "Sikh",
    8: "Other religion",
    9: "Not stated"
}

economic_activity = {
    1: "Economically active: Employee",
    2: "Economically active: Self-employed",
    3: "Economically active: Unemployed",
    4: "Economically active: Full-time student",
    5: "Economically inactive: Retired",
    6: "Economically inactive: Student",
    7: "Economically inactive: Looking after home or family",
    8: "Economically inactive: Long-term sick or disabled",
    9: "Economically inactive: Other"
}

occupation = {
    1: "Managers, Directors and Senior Officials",
    2: "Professional Occupations",
    3: "Associate Professional and Technical Occupations",
    4: "Administrative and Secretarial Occupations",
    5: "Skilled Trades Occupations",
    6: "Caring, Leisure and Other Service Occupations",
    7: "Sales and Customer Service Occupations",
    8: "Process, Plant and Machine Operatives",
    9: "Elementary Occupations"
}

industry = {
    1: "Agriculture, forestry and fishing",
    2: "Mining and quarrying; Manufacturing; Electricity, gas, steam and air conditioning system; Water supply",
    3: "Construction",
    4: "Wholesale and retail trade; Repair of motor vehicles and motorcycles",
    5: "Accommodation and food service activities",
    6: "Transport and storage; Information and communication",
    7: "Financial and insurance activities; Intermediation",
    8: "Real estate activities; Professional, scientific and technical activities; Administrative and support service activities",
    9: "Public administration and defence; compulsory social security",
    10: "Education",
    11: "Human health and social work activities",
    12: "Other community, social and personal service activities; Private households employing domestic staff; Extra-territorial organisations and bodies"
}

hours = {
    1: "Part-time: 15 or less hours worked",
    2: "Part-time: 16 to 30 hours worked",
    3: "Full-time: 31 to 48 hours worked",
    4: "Full-time: 49 or more hours worked"
}

social_grade = {
    1: "AB",
    2: "C1",
    3: "C2",
    4: "DE"
}

# %%
newCensus['Region'] = newCensus['Region'].map(region)
# newCensus['Residence Type'].map(resident_type)
newCensus['Family Composition'] = newCensus['Family Composition'].map(family_composition)
newCensus['Population Base'] = newCensus['Population Base'].map(population_base)
newCensus['Sex'] = newCensus['Sex'].map(sex)
newCensus['Age'] = newCensus['Age'].map(age)
newCensus['Marital Status'] = newCensus['Marital Status'].map(marital_status)
newCensus['Student'] = newCensus['Student'].map(student)
newCensus['Country of Birth'] = newCensus['Country of Birth'].map(country_of_birth)
newCensus['Health'] = newCensus['Health'].map(health)
newCensus['Ethnic Group'] = newCensus['Ethnic Group'].map(ethnic_group)
newCensus['Religion'] = newCensus['Religion'].map(religion)
newCensus['Economic Activity'] = newCensus['Economic Activity'].map(economic_activity)
newCensus['Occupation'] = newCensus['Occupation'].map(occupation)
newCensus['Industry'] = newCensus['Industry'].map(industry)
newCensus['Hours worked per week'] = newCensus['Hours worked per week'].map(hours)
newCensus['Approximated Social Grade'] = newCensus['Approximated Social Grade'].map(social_grade)

# %%
newCensus.keys()
# Out:
# Index(['Region', 'Family Composition', 'Population Base', 'Sex', 'Age',
#        'Marital Status', 'Student', 'Country of Birth', 'Health',
#        'Ethnic Group', 'Religion', 'Economic Activity', 'Occupation',
#        'Industry', 'Hours worked per week', 'No of hours',
#        'Approximated Social Grade'],
#       dtype='object')

# %%
newCensus.describe()
# Out:
#          No of hours
# count  267419.000000
# mean       35.234789
# std        13.520881
# min         1.000000
# 25%        27.000000
# 50%        37.000000
# 75%        45.000000
# max        60.000000

# %%
newCensus.isnull().sum()
# Out:
# Region                          0
# Family Composition           2251
# Population Base                 0
# Sex                             0
# Age                             0
# Marital Status                  0
# Student                         0
# Country of Birth                0
# Health                          0
# Ethnic Group                    0
# Religion                        0
# Economic Activity               0
# Occupation                      0
# Industry                        0
# Hours worked per week           0
# No of hours                     0
# Approximated Social Grade    2251
# dtype: int64

# %%
newCensus.hist(bins=18, figsize=(15,15))
# Out:
# array([[<AxesSubplot: title={'center': 'No of hours'}>]], dtype=object)

# %%
newCensus['Age'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <AxesSubplot: ylabel='Age'>

# %%
newCensus.plot(kind = 'box',figsize=(30,15))
# Out:
# <AxesSubplot: >

# %%
toPlot = newCensus.drop(['Region'], axis=1)

for attr in toPlot:
    attrBox = newCensus[attr].value_counts().plot(kind='bar')
    attrBox.set_title(attr)
    plt.show()

# %%
newCensus['Sex'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <AxesSubplot: ylabel='Sex'>

# %%
pearsoncorr = newCensus.corr(method='pearson')
pearsoncorr
# Out:
# C:\Users\Kyle\AppData\Local\Temp\ipykernel_7584\1119176227.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   pearsoncorr = newCensus.corr(method='pearson')
#              No of hours
# No of hours          1.0

# %%
newCensus.keys()
# Out:
# Index(['Region', 'Family Composition', 'Population Base', 'Sex', 'Age',
#        'Marital Status', 'Student', 'Country of Birth', 'Health',
#        'Ethnic Group', 'Religion', 'Economic Activity', 'Occupation',
#        'Industry', 'Hours worked per week', 'No of hours',
#        'Approximated Social Grade'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
newCensus['Region'] = LE.fit_transform(newCensus['Region'])
newCensus['Family Composition'] = LE.fit_transform(newCensus['Family Composition'])
newCensus['Population Base'] = LE.fit_transform(newCensus['Population Base'])
newCensus['Sex'] = LE.fit_transform(newCensus['Sex'])
newCensus['Age'] = LE.fit_transform(newCensus['Age'])
newCensus['Marital Status'] = LE.fit_transform(newCensus['Marital Status'])
newCensus['Student'] = LE.fit_transform(newCensus['Student'])
newCensus['Country of Birth'] = LE.fit_transform(newCensus['Country of Birth'])
newCensus['Health'] = LE.fit_transform(newCensus['Health'])
newCensus['Ethnic Group'] = LE.fit_transform(newCensus['Ethnic Group'])
newCensus['Religion'] = LE.fit_transform(newCensus['Religion'])
newCensus['Economic Activity'] = LE.fit_transform(newCensus['Economic Activity'])
newCensus['Occupation'] = LE.fit_transform(newCensus['Occupation'])
newCensus['Industry'] = LE.fit_transform(newCensus['Industry'])
newCensus['Hours worked per week'] = LE.fit_transform(newCensus['Hours worked per week'])
newCensus['Approximated Social Grade'] = LE.fit_transform(newCensus['Approximated Social Grade'])

# %%
newCensus.to_csv('census_num.csv')

# %%
X = newCensus.iloc[:,:-1].values
y = newCensus.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25, random_state=0)

# %%
from sklearn.tree import DecisionTreeClassifier

DT = DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
DT.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
y_pred = DT.predict(X_test)
y_pred
# Out:
# array([3, 3, 3, ..., 3, 2, 2])

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True)
# Out:
# <AxesSubplot: >

# %%
## Partitioning with Decision Tree
from sklearn import metrics
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_auc_score

print(confusion_matrix(y_test, y_pred), '\n')
print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test,y_pred))
print('Mean Squared Error: ', metrics.mean_squared_error(y_test,y_pred))
print('Root Mean Squared Error: ', np.sqrt(metrics.mean_squared_error(y_test, y_pred)), '\n')

print(classification_report(y_test, y_pred))
print("Accuracy: ", accuracy_score(y_test,y_pred))
# print("AUC: ", roc_auc_score(y_test, y_pred))
# Out:
# [[11438  3389     0     0     0]
#  [ 3535 19476   340   570     0]
#  [    0   338 10547  2243     0]
#  [    0   630  2452 11343     0]
#  [    0     0     0     0   554]]
#
# Mean Absolute Error:  0.21983396903746916
# Mean Squared Error:  0.25573255553062596
# Root Mean Squared Error:  0.505700064791993
#
#               precision    recall  f1-score   support
#
#            0       0.76      0.77      0.77     14827
#            1       0.82      0.81      0.82     23921
#            2       0.79      0.80      0.80     13128
#            3       0.80      0.79      0.79     14425
#            4       1.00      1.00      1.00       554
#
#     accuracy                           0.80     66855
#    macro avg       0.83      0.84      0.83     66855
# weighted avg       0.80      0.80      0.80     66855
#
# Accuracy:  0.7981153242091092

# %%
## Partitioning with KNN
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=5, metric='minkowski', p=2)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)

print(confusion_matrix(y_test, y_pred), '\n')
print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test,y_pred))
print('Mean Squared Error: ', metrics.mean_squared_error(y_test,y_pred))
print('Root Mean Squared Error: ', np.sqrt(metrics.mean_squared_error(y_test, y_pred)), '\n')

print(classification_report(y_test, y_pred))
print("Accuracy: ", accuracy_score(y_test,y_pred))
# Out:
# [[10725  2636   353  1111     2]
#  [ 3342 18183   887  1502     7]
#  [ 1193  1404  8745  1786     0]
#  [ 2184  1814  2094  8333     0]
#  [   91   194    30    90   149]]
#
# Mean Absolute Error:  0.491855508189365
# Mean Squared Error:  0.9686485677959764
# Root Mean Squared Error:  0.9841994552914447
#
#               precision    recall  f1-score   support
#
#            0       0.61      0.72      0.66     14827
#            1       0.75      0.76      0.76     23921
#            2       0.72      0.67      0.69     13128
#            3       0.65      0.58      0.61     14425
#            4       0.94      0.27      0.42       554
#
#     accuracy                           0.69     66855
#    macro avg       0.74      0.60      0.63     66855
# weighted avg       0.69      0.69      0.69     66855
#
# Accuracy:  0.6900755366090794

# %%
## Partitioning with QDA

from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

qda = QuadraticDiscriminantAnalysis()
qda.fit(X_train, y_train)
y_test = qda.predict(X_test)

print(confusion_matrix(y_test, y_pred), '\n')
print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test,y_pred))
print('Mean Squared Error: ', metrics.mean_squared_error(y_test,y_pred))
print('Root Mean Squared Error: ', np.sqrt(metrics.mean_squared_error(y_test, y_pred)), '\n')

print(classification_report(y_test, y_pred))
print("Accuracy: ", accuracy_score(y_test,y_pred))
# Out:
# C:\Users\Kyle\AppData\Roaming\Python\Python310\site-packages\sklearn\discriminant_analysis.py:887: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# [[15356 19357 10466 10951    57]
#  [  402  2181   296   484     1]
#  [ 1505  2194  1172  1129     7]
#  [  213   360   159   210     0]
#  [   59   139    16    48    93]]
#
# Mean Absolute Error:  1.2510208660533992
# Mean Squared Error:  2.6703911450153317
# Root Mean Squared Error:  1.6341331478846306
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.27      0.42     56187
#            1       0.09      0.65      0.16      3364
#            2       0.10      0.20      0.13      6007
#            3       0.02      0.22      0.03       942
#            4       0.59      0.26      0.36       355
#
#     accuracy                           0.28     66855
#    macro avg       0.33      0.32      0.22     66855
# ...

# %%
from sklearn.linear_model import LinearRegression

LR = LinearRegression()

LR.fit(X_train, y_train)

y_pred = LR.predict(X_test)

from sklearn.metrics import r2_score

print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test,y_pred))
print('Mean Squared Error: ', metrics.mean_squared_error(y_test,y_pred))
print('Root Mean Squared Error: ', np.sqrt(metrics.mean_squared_error(y_test, y_pred)), '\n')

print("R2 Score: ", r2_score(y_test, y_pred))

adj_r2 = 1 - (1-r2_score(y_test, y_pred))*(len(y_pred)-1)/(len(y_pred)-X_test.shape[1]-1)
print(adj_r2)
# Out:
# Mean Absolute Error:  1.3129525683759422
# Mean Squared Error:  1.9415401505015353
# Root Mean Squared Error:  1.3933915998388735
#
# R2 Score:  -2.626783067471834
# -2.6276512641425835

# %%
from sklearn.linear_model import SGDRegressor

sgdr = SGDRegressor()

sgdr.fit(X_train, y_train)

y_pred = sgdr.predict(X_test)


print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test,y_pred))
print('Mean Squared Error: ', metrics.mean_squared_error(y_test,y_pred))
print('Root Mean Squared Error: ', np.sqrt(metrics.mean_squared_error(y_test, y_pred)), '\n')

print("R2 Score: ", r2_score(y_test, y_pred))

adj_r2 = 1 - (1-r2_score(y_test, y_pred))*(len(y_pred)-1)/(len(y_pred)-X_test.shape[1]-1)
print(adj_r2)
# Out:
# Mean Absolute Error:  1.2008177674529599
# Mean Squared Error:  1.6691516582791905
# Root Mean Squared Error:  1.2919565233703456
#
# R2 Score:  -2.117963318824868
# -2.1187097117914617

# %%
newCensus.keys()
# Out:
# Index(['Region', 'Family Composition', 'Population Base', 'Sex', 'Age',
#        'Marital Status', 'Student', 'Country of Birth', 'Health',
#        'Ethnic Group', 'Religion', 'Economic Activity', 'Occupation',
#        'Industry', 'Hours worked per week', 'No of hours',
#        'Approximated Social Grade'],
#       dtype='object')

# %%
# Change -9 values to 0
newCensus = census.replace(-9, 0)
newCensus.dropna(inplace=True)
del newCensus['Person ID']
del newCensus['Residence Type']

# %%
region = {
    "E12000001": "North East",
    "E12000002": "North West",
    "E12000003": "Yorkshire and the Humber",
    "E12000004": "East Midlands",
    "E12000005": "West Midlands",
    "E12000006": "East of England",
    "E12000007": "London",
    "E12000008": "South East",
    "E12000009": "South West",
    "W92000004": "Wales"
}

family_composition = {
    1: "Not in a family",
    2: "Married/same-sex civil partnership couple family",
    3: "Cohabiting couple family",
    4: "Lone parent family (male head)",
    5: "Lone parent family (female head)",
    6: "Other related family"
}

population_base = {
    1: "Usual resident",
    2: "Student living away from home during term-time",
    3: "Short-term resident"
}

sex = {
    1: "Male",
    2: "Female"
}

age = {
    1: "0 to 15",
    2: "16 to 24",
    3: "25 to 34",
    4: "35 to 44",
    5: "45 to 54",
    6: "55 to 64",
    7: "65 to 74",
    8: "75 and over"
}

marital_status = {
    1: "Single ",
    2: "Married",
    3: "Separated",
    4: "Divorced",
    5: "Widowed"
}

student = {
    1: "Yes",
    2: "No"
}

country_of_birth = {
    1: "UK",
    2: "Non UK"
}

health = {
    1: "Very good health",
    2: "Good health",
    3: "Fair health",
    4: "Bad health",
    5: "Very bad health"
}

ethnic_group = {
    1: "White",
    2: "Mixed",
    3: "Asian and Asian British",
    4: "Black or Black British",
    5: "Chinese or Other ethnic group"
}

religion = {
    1: "No religion",
    2: "Christian",
    3: "Buddhist",
    4: "Hindu",
    5: "Jewish",
    6: "Muslim",
    7: "Sikh",
    8: "Other religion",
    9: "Not stated"
}

economic_activity = {
    1: "Economically active: Employee",
    2: "Economically active: Self-employed",
    3: "Economically active: Unemployed",
    4: "Economically active: Full-time student",
    5: "Economically inactive: Retired",
    6: "Economically inactive: Student",
    7: "Economically inactive: Looking after home or family",
    8: "Economically inactive: Long-term sick or disabled",
    9: "Economically inactive: Other"
}

occupation = {
    1: "Managers, Directors and Senior Officials",
    2: "Professional Occupations",
    3: "Associate Professional and Technical Occupations",
    4: "Administrative and Secretarial Occupations",
    5: "Skilled Trades Occupations",
    6: "Caring, Leisure and Other Service Occupations",
    7: "Sales and Customer Service Occupations",
    8: "Process, Plant and Machine Operatives",
    9: "Elementary Occupations"
}

industry = {
    1: "Agriculture, forestry and fishing",
    2: "Mining and quarrying; Manufacturing; Electricity, gas, steam and air conditioning system; Water supply",
    3: "Construction",
    4: "Wholesale and retail trade; Repair of motor vehicles and motorcycles",
    5: "Accommodation and food service activities",
    6: "Transport and storage; Information and communication",
    7: "Financial and insurance activities; Intermediation",
    8: "Real estate activities; Professional, scientific and technical activities; Administrative and support service activities",
    9: "Public administration and defence; compulsory social security",
    10: "Education",
    11: "Human health and social work activities",
    12: "Other community, social and personal service activities; Private households employing domestic staff; Extra-territorial organisations and bodies"
}

hours = {
    1: "Part-time: 15 or less hours worked",
    2: "Part-time: 16 to 30 hours worked",
    3: "Full-time: 31 to 48 hours worked",
    4: "Full-time: 49 or more hours worked"
}

social_grade = {
    1: "AB",
    2: "C1",
    3: "C2",
    4: "DE"
}

# %%
newCensus['Region'] = newCensus['Region'].map(region)
# newCensus['Residence Type'].map(resident_type)
newCensus['Family Composition'] = newCensus['Family Composition'].map(family_composition)
newCensus['Population Base'] = newCensus['Population Base'].map(population_base)
newCensus['Sex'] = newCensus['Sex'].map(sex)
newCensus['Age'] = newCensus['Age'].map(age)
newCensus['Marital Status'] = newCensus['Marital Status'].map(marital_status)
newCensus['Student'] = newCensus['Student'].map(student)
newCensus['Country of Birth'] = newCensus['Country of Birth'].map(country_of_birth)
newCensus['Health'] = newCensus['Health'].map(health)
newCensus['Ethnic Group'] = newCensus['Ethnic Group'].map(ethnic_group)
newCensus['Religion'] = newCensus['Religion'].map(religion)
newCensus['Economic Activity'] = newCensus['Economic Activity'].map(economic_activity)
newCensus['Occupation'] = newCensus['Occupation'].map(occupation)
newCensus['Industry'] = newCensus['Industry'].map(industry)
newCensus['Hours worked per week'] = newCensus['Hours worked per week'].map(hours)
newCensus['Approximated Social Grade'] = newCensus['Approximated Social Grade'].map(social_grade)

# %%
newCensus["No of hours"] = pd.qcut(newCensus["No of hours"], q=4, duplicates="drop")
newCensus["No of hours"].value_counts(sort=False)
# Out:
# (0.999, 27.0]    67505
# (27.0, 37.0]     70080
# (37.0, 45.0]     68760
# (45.0, 60.0]     61074
# Name: No of hours, dtype: int64

# %%
newCensus1 = newCensus.sample(frac=0.01, replace=False, random_state=1)
newCensus1.shape
# Out:
# (2674, 17)

# %%
from apyori import apriori

data_list = []
for row in range(0,2674):
    data_list.append([str(newCensus1.values[row,column]) for column in range(0,14)])

rules = apriori(data_list, min_support=0.25, min_confidence=0.25, min_length=2)
results = list(rules)

# %%
df = pd.DataFrame(columns=('Items', 'Antecedent','Consequent', 'Support', 'Confidence','Lift'))

Support = []
Confidence = []
Lift = []
Items = []
Antecedent = []
Consequent = []

for RelationRecord in results:
    for ordered_stat in RelationRecord.ordered_statistics:
        Support.append(RelationRecord.support)
        Items.append(RelationRecord.items)
        Antecedent.append(ordered_stat.items_base)
        Consequent.append(ordered_stat.items_add)
        Confidence.append(ordered_stat.confidence)
        Lift.append(ordered_stat.lift)

df['Items'] = list(map(set,Items))
df['Antecedent'] = list(map(set, Antecedent))
df['Consequent'] = list(map(set, Consequent))
df['Support'] = Support
df['Confidence'] = Confidence
df['Lift'] = Lift

df.sort_values(by = 'Lift', ascending = False, inplace = True)

# %%
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#                                                Items  \
# 0  {Married/same-sex civil partnership couple fam...
# 1  {Married/same-sex civil partnership couple fam...
# 2  {Married/same-sex civil partnership couple fam...
# 3  {Married/same-sex civil partnership couple fam...
# 4  {Married/same-sex civil partnership couple fam...
#
#                                           Antecedent  \
# 0                           {UK, Christian, Married}
# 1           {UK, Christian, Married, Usual resident}
# 2  {No, Married/same-sex civil partnership couple...
# 3  {No, Married/same-sex civil partnership couple...
# 4  {No, Married/same-sex civil partnership couple...
#
#                                           Consequent   Support  Confidence  \
# 0  {No, Married/same-sex civil partnership couple...  0.262902    0.964335
# 1  {No, Married/same-sex civil partnership couple...  0.262902    0.964335
# 2                           {UK, Christian, Married}  0.262902    0.564205
# ...

# %%
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

newCensus = pd.read_csv("census_num.csv", index_col=[0])

# %%
scaler = StandardScaler()
scaled_features = scaler.fit_transform(newCensus.values)
scaled_features_adult = pd.DataFrame(scaled_features, index=newCensus.index, columns = newCensus.columns)
scaled_features_adult.describe()
# Out:
#              Region  Family Composition  Population Base           Sex  \
# count  2.674190e+05        2.674190e+05     2.674190e+05  2.674190e+05
# mean  -1.300886e-16        9.182727e-17     1.153793e-15  1.020303e-16
# std    1.000002e+00        1.000002e+00     1.000002e+00  1.000002e+00
# min   -1.580695e+00       -1.857975e+00    -2.167506e+01 -1.060981e+00
# 25%   -8.554894e-01       -4.016892e-01     4.613598e-02 -1.060981e+00
# 50%   -1.302837e-01        3.264540e-01     4.613598e-02  9.425244e-01
# 75%    5.949220e-01        3.264540e-01     4.613598e-02  9.425244e-01
# max    1.682731e+00        2.510883e+00     4.613598e-02  9.425244e-01
#
#                 Age  Marital Status       Student  Country of Birth  \
# count  2.674190e+05    2.674190e+05  2.674190e+05      2.674190e+05
# mean   9.820416e-17   -4.378800e-17  1.785530e-17      7.992374e-17
# std    1.000002e+00    1.000002e+00  1.000002e+00      1.000002e+00
# ...

# %%
## KMeans

kmeans = KMeans(n_clusters=2, random_state=0)
kmeans.fit(scaled_features_adult)
kmeans.cluster_centers_
# Out:
# array([[-0.0137082 ,  0.00152204,  0.00447591,  0.20192676, -0.01717272,
#          0.0064822 , -0.15856954, -0.00305299,  0.03200309,  0.01715843,
#          0.02049457, -0.04670499,  0.0487076 ,  0.0169076 , -0.60147777,
#          0.52377677, -0.1267991 ],
#        [ 0.03319706, -0.00368591, -0.01083928, -0.48900465,  0.04158707,
#         -0.01569791,  0.38400676,  0.0073934 , -0.07750167, -0.04155244,
#         -0.04963155,  0.11310516, -0.11795487, -0.04094502,  1.45659456,
#         -1.26842657,  0.3070685 ]])

# %%
kmeans_silhouette = silhouette_score(scaled_features_adult, kmeans.labels_).round(2)
kmeans_silhouette
# Out:
# 0.15

# %%
from yellowbrick.cluster import KElbowVisualizer, SilhouetteVisualizer

model = KMeans()
visualizer = KElbowVisualizer(model, k=(2,10), metric='calinski_harabasz')

visualizer.fit(scaled_features_adult)
visualizer.show()
# Out:
# <AxesSubplot: title={'center': 'Calinski Harabasz Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='calinski harabasz score'>

# %%
visualizer = SilhouetteVisualizer(model)
visualizer.fit(scaled_features_adult)
visualizer.poof()
# Out:
# C:\Users\Kyle\AppData\Roaming\Python\Python310\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but KMeans was fitted with feature names
#   warnings.warn(
# <AxesSubplot: title={'center': 'Silhouette Plot of KMeans Clustering for 267419 Samples in 9 Centers'}, xlabel='silhouette coefficient values', ylabel='cluster label'>

# %%
scaled_features_adult['cluster'] = kmeans.labels_

# %%
cluster1 = scaled_features_adult.query("cluster == 0")
cluster2 = scaled_features_adult.query("cluster == 1")

# %%
cluster1.head()
# Out:
#           Region  Family Composition  Population Base       Sex       Age  \
# 380230 -0.492887           -1.857975         0.046136 -1.060981 -0.116632
# 380231 -0.492887           -1.857975         0.046136 -1.060981 -1.578699
# 380232 -0.492887           -1.857975         0.046136  0.942524  0.614402
# 380233 -0.492887            0.326454         0.046136  0.942524  1.345436
# 380234 -0.492887            1.054597         0.046136  0.942524 -0.847666
#
#         Marital Status   Student  Country of Birth    Health  Ethnic Group  \
# 380230        1.155292 -0.204782          0.431325  0.965420      0.346818
# 380231        1.155292 -0.204782          0.431325 -0.759865      0.346818
# 380232       -1.566932 -0.204782          0.431325  0.965420      0.346818
# 380233       -0.659524 -0.204782          0.431325 -0.759865      0.346818
# 380234        1.155292 -0.204782          0.431325 -1.622507      0.346818
#
#         Religion  Economic Activity  Occupation  Industry  \
# ...

# %%
cluster1.shape
# Out:
# (189274, 18)

# %%
cluster1.describe()
# Out:
#               Region  Family Composition  Population Base            Sex  \
# count  189274.000000       189274.000000    189274.000000  189274.000000
# mean       -0.013710            0.001553         0.004248       0.201888
# std         0.996943            1.019603         0.952942       0.967125
# min        -1.580695           -1.857975       -21.675057      -1.060981
# 25%        -0.855489           -0.401689         0.046136      -1.060981
# 50%        -0.130284            0.326454         0.046136       0.942524
# 75%         0.594922            0.326454         0.046136       0.942524
# max         1.682731            2.510883         0.046136       0.942524
#
#                  Age  Marital Status        Student  Country of Birth  \
# count  189274.000000   189274.000000  189274.000000     189274.000000
# mean       -0.017212        0.006518      -0.158330         -0.003090
# std         0.940310        0.998227       0.483934          1.002910
# ...

# %%
cluster2.head()
# Out:
#           Region  Family Composition  Population Base       Sex       Age  \
# 302321 -0.492887           -1.129832         0.046136 -1.060981  0.614402
# 302322 -0.492887            0.326454         0.046136 -1.060981 -1.578699
# 302323 -0.492887            0.326454         0.046136 -1.060981  0.614402
# 302324 -0.492887            0.326454         0.046136 -1.060981  1.345436
# 302325 -0.492887           -1.129832         0.046136 -1.060981  1.345436
#
#         Marital Status   Student  Country of Birth    Health  Ethnic Group  \
# 302321       -1.566932 -0.204782          0.431325 -1.622507      0.346818
# 302322        1.155292  4.883251          0.431325  0.965420      0.346818
# 302323       -0.659524 -0.204782          0.431325 -1.622507      0.346818
# 302324       -0.659524 -0.204782          0.431325  0.965420      0.346818
# 302325        0.247884 -0.204782          0.431325 -0.759865      0.346818
#
#         Religion  Economic Activity  Occupation  Industry  \
# ...

# %%
cluster1_mean = kmeans.cluster_centers_[0]
cluster2_mean = kmeans.cluster_centers_[1]

cluster1_mean_p1 = cluster1_mean[:8]
cluster2_mean_p1 = cluster2_mean[:8]

X = cluster1.keys()[:8]

X_axis = np.arange(len(X))

plt.bar(X_axis - 0.2, cluster1_mean_p1, 0.4, label = 'Cluster1')
plt.bar(X_axis + 0.2, cluster2_mean_p1, 0.4, label = 'Cluster2')

plt.xticks(X_axis, X, rotation='vertical')
plt.xlabel("Groups")
plt.ylabel("Mean values")
plt.title("Mean values per attribute")
plt.legend()
plt.show()

# %%
cluster1_mean_p2 = cluster1_mean[8:]
cluster2_mean_p2 = cluster2_mean[8:]

X = cluster1.keys()[8:-1]

X_axis = np.arange(len(X))

plt.bar(X_axis - 0.2, cluster1_mean_p2, 0.4, label = 'Cluster1')
plt.bar(X_axis + 0.2, cluster2_mean_p2, 0.4, label = 'Cluster2')

plt.xticks(X_axis, X, rotation='vertical')
plt.xlabel("Groups")
plt.ylabel("Mean values")
plt.title("Mean values per attribute")
plt.legend()
plt.show()

# %%
## Hierarchical Clustering

from sklearn.cluster import AgglomerativeClustering

X = scaled_features_adult.sample(frac=0.1, replace=False, random_state=1)
cluster = AgglomerativeClustering(distance_threshold=0, n_clusters=None)

cluster.fit(X)
# Out:
# AgglomerativeClustering(distance_threshold=0, n_clusters=None)

# %%
plt.scatter(X['Age'], X['No of hours'], c=cluster.labels_,cmap='rainbow')

# %%
from scipy.cluster.hierarchy import dendrogram

def plot_dendrogram(model, **kwargs):
    counts = np.zeros(model.children_.shape[0])
    n_samples = len(model.labels_)
    for i, merge in enumerate(model.children_):
        current_count = 0
        for child_idx in merge:
            if child_idx < n_samples:
                current_count += 1
            else:
                current_count += counts[child_idx - n_samples]
        counts[i] = current_count
    linkage_matrix = np.column_stack([model.children_,model.distances_,counts]).astype(float)

    dendrogram(linkage_matrix, **kwargs)

plt.title("Hierarchical Clustering Dendrogram")
plot_dendrogram(cluster)
plt.xlabel("Number of points in node (or index of point if no parenthesis).")
plt.show()

# %%
cluster = AgglomerativeClustering(n_clusters=3, affinity='euclidean', linkage='ward')
cluster.fit_predict(X)
plt.figure(figsize=(10,7))
plt.scatter(X['Age'],X['No of hours'],c = cluster.labels_, cmap='rainbow')

# %%
X['cluster'] = cluster.labels_
cluster1= X.query("cluster == 0")
cluster2 = X.query("cluster == 1")
cluster3 = X.query("cluster == 2")

# %%
cluster1.describe()
# Out:
#              Region  Family Composition  Population Base           Sex  \
# count  19935.000000        19935.000000     19935.000000  19935.000000
# mean      -0.029006            0.013208        -0.013792      0.177504
# std        0.996972            1.017572         1.139378      0.973403
# min       -1.580695           -1.857975       -21.675057     -1.060981
# 25%       -0.855489           -0.401689         0.046136     -1.060981
# 50%       -0.130284            0.326454         0.046136      0.942524
# 75%        0.594922            0.326454         0.046136      0.942524
# max        1.682731            2.510883         0.046136      0.942524
#
#                 Age  Marital Status       Student  Country of Birth  \
# count  19935.000000    19935.000000  19935.000000      19935.000000
# mean      -0.022388       -0.003332     -0.202485         -0.117525
# std        0.934531        0.996967      0.108088          1.099105
# ...

# %%
cluster2.describe()
# Out:
#             Region  Family Composition  Population Base          Sex  \
# count  5747.000000         5747.000000     5.747000e+03  5747.000000
# mean      0.086193           -0.071383     4.613598e-02    -0.579888
# std       1.005619            0.916255     6.939498e-18     0.855890
# min      -1.580695           -1.857975     4.613598e-02    -1.060981
# 25%      -0.855489           -1.129832     4.613598e-02    -1.060981
# 50%       0.232319            0.326454     4.613598e-02    -1.060981
# 75%       0.957525            0.326454     4.613598e-02    -1.060981
# max       1.682731            2.510883     4.613598e-02     0.942524
#
#                Age  Marital Status       Student  Country of Birth  \
# count  5747.000000     5747.000000  5.747000e+03       5747.000000
# mean      0.289272       -0.145584 -2.047816e-01          0.429411
# std       1.070921        0.980095  2.775799e-17          0.072526
# min      -1.578699       -1.566932 -2.047816e-01         -2.318440
# ...

# %%
cluster3.describe()
# Out:
#             Region  Family Composition  Population Base          Sex  \
# count  1060.000000         1060.000000     1.060000e+03  1060.000000
# mean      0.045202            0.208302     4.613598e-02    -0.189645
# std       0.985891            1.089769     6.942169e-18     0.993696
# min      -1.580695           -1.857975     4.613598e-02    -1.060981
# 25%      -0.855489           -0.401689     4.613598e-02    -1.060981
# 50%       0.232319            0.326454     4.613598e-02    -1.060981
# 75%       0.957525            1.054597     4.613598e-02     0.942524
# max       1.682731            2.510883     4.613598e-02     0.942524
#
#                Age  Marital Status      Student  Country of Birth  \
# count  1060.000000     1060.000000  1060.000000       1060.000000
# mean     -1.313872        0.960113     4.883251         -0.110846
# std       0.600633        0.601259     0.000000          1.094542
# min      -1.578699       -1.566932     4.883251         -2.318440
# ...

# %%
cluster1_mean = np.array(cluster1.mean())
cluster2_mean = np.array(cluster2.mean())
cluster3_mean = np.array(cluster3.mean())

# %%
cluster1_mean
# Out:
# array([-0.0290059 ,  0.01320814, -0.01379207,  0.17750411, -0.02238765,
#        -0.00333174, -0.20248453, -0.11752489,  0.02813196, -0.09159006,
#         0.03605607, -0.05371377,  0.03513516,  0.02822692, -0.46471522,
#         0.4176197 , -0.09209109,  0.        ])

# %%
cluster1_mean_p1 = cluster1_mean[:8]
cluster2_mean_p1 = cluster2_mean[:8]
cluster3_mean_p1 = cluster3_mean[:8]

# %%
cluster1_mean_p1
# Out:
# array([-0.0290059 ,  0.01320814, -0.01379207,  0.17750411, -0.02238765,
#        -0.00333174, -0.20248453, -0.11752489])

# %%
X = cluster1.keys()[:8]

X_axis = np.arange(len(X))

plt.bar(X_axis - 0.2, cluster1_mean_p1, 0.3, label = 'Cluster1')
plt.bar(X_axis + 0.1, cluster2_mean_p1, 0.3, label = 'Cluster2')
plt.bar(X_axis + 0.4, cluster3_mean_p1, 0.3, label = 'Cluster3')

plt.xticks(X_axis, X, rotation='vertical')
plt.xlabel("Groups")
plt.ylabel("Mean values")
plt.title("Mean values per attribute")
plt.legend()
plt.show()

# %%
cluster1_mean_p2 = cluster1_mean[8:-2]
cluster2_mean_p2 = cluster2_mean[8:-2]
cluster3_mean_p2 = cluster3_mean[8:-2]

X = cluster1.keys()[8:-2]

X_axis = np.arange(len(X))

plt.bar(X_axis - 0.2, cluster1_mean_p2, 0.3, label = 'Cluster1')
plt.bar(X_axis + 0.1, cluster2_mean_p2, 0.3, label = 'Cluster2')
plt.bar(X_axis + 0.4, cluster3_mean_p2, 0.3, label = 'Cluster3')

plt.xticks(X_axis, X, rotation='vertical')
plt.xlabel("Groups")
plt.ylabel("Mean values")
plt.title("Mean values per attribute")
plt.legend()
plt.show()
